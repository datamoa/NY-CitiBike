# %%
import pandas as pd

# %%
# Name of the CSV file
path1 = "201908-citibike-tripdata.csv"
# Use encoding to read the CSV in pandas
table_aug =pd.read_csv(path1, encoding="UTF-8")
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           393  2019-08-01 00:00:01.4680  2019-08-01 00:06:35.3780
# 1           627  2019-08-01 00:00:01.9290  2019-08-01 00:10:29.7840
# 2          1132  2019-08-01 00:00:04.0480  2019-08-01 00:18:56.1650
# 3          1780  2019-08-01 00:00:04.1630  2019-08-01 00:29:44.7940
# 4          1517  2019-08-01 00:00:05.4580  2019-08-01 00:25:23.4550
#
#    start station id              start station name  start station latitude  \
# 0             531.0          Forsyth St & Broome St               40.718939
# 1             274.0  Lafayette Ave & Fort Greene Pl               40.686919
# 2            2000.0        Front St & Washington St               40.702551
# 3             479.0                 9 Ave & W 45 St               40.760193
# 4            3312.0                 1 Ave & E 94 St               40.781721
#
#    start station longitude  end station id            end station name  \
# ...

# %%
# Name of the CSV file
path2 = "201907-citibike-tripdata.csv"
# Use encoding to read the CSV in pandas
table_jul =pd.read_csv(path2, encoding="UTF-8")
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           897  2019-07-01 00:00:00.1320  2019-07-01 00:14:58.0040
# 1           267  2019-07-01 00:00:05.1780  2019-07-01 00:04:32.4500
# 2          2201  2019-07-01 00:00:05.2130  2019-07-01 00:36:46.7490
# 3          1660  2019-07-01 00:00:08.6010  2019-07-01 00:27:48.8050
# 4           109  2019-07-01 00:00:12.1580  2019-07-01 00:02:01.5670
#
#    start station id       start station name  start station latitude  \
# 0             493.0          W 45 St & 6 Ave               40.756800
# 1            3143.0          5 Ave & E 78 St               40.776321
# 2             317.0        E 6 St & Avenue B               40.724537
# 3             249.0  Harrison St & Hudson St               40.718710
# 4            3552.0      W 113 St & Broadway               40.805973
#
#    start station longitude  end station id             end station name  \
# ...

# %%
# Name of the CSV file
path3 = "201906-citibike-tripdata.csv"
# Use encoding to read the CSV in pandas
table_jun =pd.read_csv(path3, encoding="UTF-8")
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           330  2019-06-01 00:00:01.5000  2019-06-01 00:05:31.7600
# 1           830  2019-06-01 00:00:04.2400  2019-06-01 00:13:55.1470
# 2           380  2019-06-01 00:00:06.0190  2019-06-01 00:06:26.7790
# 3          1155  2019-06-01 00:00:06.7760  2019-06-01 00:19:22.5380
# 4          1055  2019-06-01 00:00:07.5200  2019-06-01 00:17:42.5580
#
#    start station id       start station name  start station latitude  \
# 0              3602           31 Ave & 34 St               40.763154
# 1              3054  Greene Ave & Throop Ave               40.689493
# 2               229           Great Jones St               40.727434
# 3              3771  McKibbin St & Bogart St               40.706237
# 4               441          E 52 St & 2 Ave               40.756014
#
#    start station longitude  end station id       end station name  \
# 0               -73.920827            3570         35 Ave & 37 St
# ...

# %%
table = table_jun.append(table_jul, ignore_index=True)
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 330  2019-06-01 00:00:01.5000  2019-06-01 00:05:31.7600
# 1                 830  2019-06-01 00:00:04.2400  2019-06-01 00:13:55.1470
# 2                 380  2019-06-01 00:00:06.0190  2019-06-01 00:06:26.7790
# 3                1155  2019-06-01 00:00:06.7760  2019-06-01 00:19:22.5380
# 4                1055  2019-06-01 00:00:07.5200  2019-06-01 00:17:42.5580
# 5                 128  2019-06-01 00:00:07.9860  2019-06-01 00:02:16.3950
# 6                 315  2019-06-01 00:00:09.1960  2019-06-01 00:05:24.8050
# 7                 471  2019-06-01 00:00:14.6440  2019-06-01 00:08:05.9930
# 8                1554  2019-06-01 00:00:18.1970  2019-06-01 00:26:12.7890
# 9                 392  2019-06-01 00:00:18.6680  2019-06-01 00:06:51.4440
# 10                588  2019-06-01 00:00:19.2910  2019-06-01 00:10:08.1860
# 11               1906  2019-06-01 00:00:22.8960  2019-06-01 00:32:09.5860
# ...

# %%
table = table.append(table_aug, ignore_index=True)
table
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 330  2019-06-01 00:00:01.5000  2019-06-01 00:05:31.7600
# 1                 830  2019-06-01 00:00:04.2400  2019-06-01 00:13:55.1470
# 2                 380  2019-06-01 00:00:06.0190  2019-06-01 00:06:26.7790
# 3                1155  2019-06-01 00:00:06.7760  2019-06-01 00:19:22.5380
# 4                1055  2019-06-01 00:00:07.5200  2019-06-01 00:17:42.5580
# 5                 128  2019-06-01 00:00:07.9860  2019-06-01 00:02:16.3950
# 6                 315  2019-06-01 00:00:09.1960  2019-06-01 00:05:24.8050
# 7                 471  2019-06-01 00:00:14.6440  2019-06-01 00:08:05.9930
# 8                1554  2019-06-01 00:00:18.1970  2019-06-01 00:26:12.7890
# 9                 392  2019-06-01 00:00:18.6680  2019-06-01 00:06:51.4440
# 10                588  2019-06-01 00:00:19.2910  2019-06-01 00:10:08.1860
# 11               1906  2019-06-01 00:00:22.8960  2019-06-01 00:32:09.5860
# ...

# %%
# Identify incomplete rows
table.count()
# Out:
# tripduration               6650658
# starttime                  6650658
# stoptime                   6650658
# start station id           6650515
# start station name         6650515
# start station latitude     6650658
# start station longitude    6650658
# end station id             6650515
# end station name           6650515
# end station latitude       6650658
# end station longitude      6650658
# bikeid                     6650658
# usertype                   6650658
# birth year                 6650658
# gender                     6650658
# dtype: int64

# %%
table['gender'].value_counts()
# Out:
# 1    4370487
# 2    1659936
# 0     620235
# Name: gender, dtype: int64

# %%
table1 = table[table.gender != 0]
table1['gender'].value_counts()
# Out:
# 1    4370487
# 2    1659936
# Name: gender, dtype: int64

# %%
table1['birth year'].value_counts()
# Out:
# 1989    283772
# 1990    283277
# 1991    271339
# 1992    269829
# 1988    262608
# 1993    249014
# 1987    235268
# 1986    222772
# 1994    222613
# 1985    212586
# 1984    192842
# 1995    190207
# 1983    177014
# 1982    164569
# 1981    152427
# 1980    142038
# 1979    131057
# 1996    119389
# 1978    113080
# 1976    107928
# 1977    107883
# 1975    103393
# 1970    100192
# 1974     95452
# 1972     93078
# 1971     93041
# 1973     91736
# 1969     89297
# 1968     84846
# 1967     83261
#          ...
# 1890       187
# 1901       181
# 1924       148
# 1928       147
# 1896       136
# 1933       114
# 1893       107
# 1911       106
# 1917        99
# 1934        98
# 1886        72
# 1931        67
# 1921        66
# 1918        61
# 1885        59
# 1899        52
# 1929        46
# 1919        29
# 1915        20
# 1910        17
# 1923        16
# 1913        13
# 1922        13
# 1895        11
# 1904         9
# 1907         6
# 1926         6
# ...

# %%
table1 = table1[table1['birth year'] > 1900]

# %%
table1['birth year'].value_counts()
# Out:
# 1989    283772
# 1990    283277
# 1991    271339
# 1992    269829
# 1988    262608
# 1993    249014
# 1987    235268
# 1986    222772
# 1994    222613
# 1985    212586
# 1984    192842
# 1995    190207
# 1983    177014
# 1982    164569
# 1981    152427
# 1980    142038
# 1979    131057
# 1996    119389
# 1978    113080
# 1976    107928
# 1977    107883
# 1975    103393
# 1970    100192
# 1974     95452
# 1972     93078
# 1971     93041
# 1973     91736
# 1969     89297
# 1968     84846
# 1967     83261
#          ...
# 1937      1003
# 1936       784
# 1939       639
# 1935       527
# 1932       524
# 1938       366
# 1930       284
# 1901       181
# 1924       148
# 1928       147
# 1933       114
# 1911       106
# 1917        99
# 1934        98
# 1931        67
# 1921        66
# 1918        61
# 1929        46
# 1919        29
# 1915        20
# 1910        17
# 1923        16
# 1922        13
# 1913        13
# 1904         9
# 1907         6
# 1926         6
# ...

# %%
table2 = table1.replace(to_replace = 1,
                 value = "Male")
table2 = table2.replace(to_replace = 2, 
                 value ="Female") 
table2['gender'].value_counts()
# Out:
# Male      4369054
# Female    1659418
# Name: gender, dtype: int64

# %%
table2.to_csv(r'citibike_summer_2019.csv', index=False)
